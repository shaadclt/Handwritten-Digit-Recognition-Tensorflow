# %% [markdown]
# # Importing Tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# # Loading the data

# %%
mnist = tf.keras.datasets.mnist

(x_train,y_train), (x_test,y_test) = mnist.load_data()
x_train, x_test = x_train/ 255.0, x_test/255.0
print("x_train.shape:",x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train.shape: (60000, 28, 28)

# %% [markdown]
# # Building the model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10,activation='softmax')
])

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer='adam',
                 loss = 'sparse_categorical_crossentropy',
                 metrics = ['accuracy'])

# %% [markdown]
# # Train the model

# %%
r = model.fit(x_train,y_train, validation_data=(x_test, y_test),epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 3ms/step - loss: 0.2978 - accuracy: 0.9136 - val_loss: 0.1387 - val_accuracy: 0.9599
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1446 - accuracy: 0.9574 - val_loss: 0.0994 - val_accuracy: 0.9705
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1081 - accuracy: 0.9674 - val_loss: 0.0922 - val_accuracy: 0.9732
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0896 - accuracy: 0.9718 - val_loss: 0.0783 - val_accuracy: 0.9759
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0749 - accuracy: 0.9766 - val_loss: 0.0774 - val_accuracy: 0.9768
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0662 - accuracy: 0.9789 - val_loss: 0.0690 - val_accuracy: 0.9798
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0598 - accuracy: 0.9811 - val_loss: 0.0769 - val_accuracy: 0.9782
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0531 - accuracy: 0.9830 - val_loss: 0.0685 - val_accuracy: 0.9790
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0477 - accuracy: 0.9844 - val_loss: 0.0712 - val_accuracy: 0.9789
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0436 - accuracy: 0.9848 - val_loss: 0.0764 - val_accuracy: 0.9785

# %% [markdown]
# # Plot loss per iteration

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'],label='loss')
plt.plot(r.history['val_loss'],label='val_loss')
plt.legend()

# %% [markdown]
# # Plot accuracy per iteration

# %%
plt.plot(r.history['accuracy'],label='acc')
plt.plot(r.history['val_accuracy'],label = 'val_acc')
plt.legend()

# %% [markdown]
# # Evaluate the model

# %%
print(model.evaluate(x_test,y_test))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0764 - accuracy: 0.9785
# [0.07641947269439697, 0.9785000085830688]
